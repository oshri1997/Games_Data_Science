# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, f1_score

# %%
df=pd.read_csv("clean_df_no_rounded.csv")
df
# Out:
#                                                   Title Platforms  \
# 0                Grand Theft Auto IV    Read the review      X360
# 1         Uncharted 2: Among Thieves    Read the review       PS3
# 2                Red Dead Redemption    Read the review      X360
# 3                  God of War (2018)    Read the review       PS4
# 4                   Assassin's Creed    Read the review      X360
# ...                                                 ...       ...
# 1404  Shin Megami Tensei: Devil Survivor Overclocked...       3DS
# 1405                       Stormrise    Read the review        PC
# 1406                           Worms    Read the review       PSN
# 1407       London Detective Mysteria    Read the review       PSV
# 1408       London Detective Mysteria    Read the review       PSV
#
#                            Publisher         Genre  Total_Sales  USA_Sales  \
# 0                     Rockstar Games        Action        11.09       6.80
# ...

# %%
df['Platforms amount'] = df.groupby('Platforms')['Platforms'].transform('count')
df['Publisher movie amount'] = df.groupby('Publisher')['Publisher'].transform('count')
df['Genre Amount'] = df.groupby('Genre')['Genre'].transform('count')

# %%
X = df.drop(['Platforms','Publisher','Genre','Title','Release_Date','Total_Sales','USA_Sales','EUR_Sales','Japan_Sales'],axis=1)
y =  df['Total_Sales']

X
# Out:
#       Rating    Year  Platforms amount  Publisher movie amount  Genre Amount
# 0        9.0  2008.0               260                      18           237
# 1        9.2  2009.0               374                     126           237
# 2        9.1  2010.0               260                      18           237
# 3        9.0  2018.0                95                       9           237
# 4        7.5  2007.0               260                      83           237
# ...      ...     ...               ...                     ...           ...
# 1404     8.8  2011.0                95                      36            34
# 1405     3.1  2009.0                70                      64            34
# 1406     6.8  2009.0                 3                     126            34
# 1407     7.0  2018.0                53                      18             2
# 1408     7.0  2018.0                53                      18             2
#
# [1409 rows x 5 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1409 entries, 0 to 1408
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rating                  1409 non-null   float64
#  1   Year                    1409 non-null   float64
#  2   Platforms amount        1409 non-null   int64
#  3   Publisher movie amount  1409 non-null   int64
#  4   Genre Amount            1409 non-null   int64
# dtypes: float64(2), int64(3)
# memory usage: 55.2 KB

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
model = sklearn.linear_model.LinearRegression().fit(X_train, y_train)

# %%
newDf = pd.DataFrame({'Rating actual': y_test,'Rating predicted':model.predict(X_test)})

# %%
newDf.to_csv("Predicted.csv")

print(r2_score(y_test, newDf['Rating predicted']))
# Out:
# -0.22123179261005155

# %%
newDf
# Out:
#      Rating actual  Rating predicted
# 398           6.84          4.041497
# 238           5.10          4.139954
# 335           1.62          3.100835
# 15            1.12          4.238412
# 321           1.52          3.280750
# ..             ...               ...
# 106           3.06          4.197683
# 697           1.87          2.197718
# 415           1.87          3.983768
# 409           2.51          3.671395
# 218           1.45          3.562666
#
# [142 rows x 2 columns]
