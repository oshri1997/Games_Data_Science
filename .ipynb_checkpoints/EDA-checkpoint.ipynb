# %%
import numpy as np
import pandas as pd
import matplotlib as plot
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("clean_df.csv")
df
# Out:
#       Unnamed: 0                                    Title Platforms  \
# 0              0            Grand Theft Auto: San Andreas       PS2
# 1              1                       Grand Theft Auto V       PS4
# 2              2                       Grand Theft Auto V      X360
# 3              3   Grand Theft Auto IV    Read the review      X360
# 4              4               Uncharted 4: A Thief's End       PS4
# ...          ...                                      ...       ...
# 4396       63843             Tokyo Twilight Ghost Hunters       PS3
# 4397       63844                              Steins;Gate       PS3
# 4398       63936  Tears to Tiara II: Heir of the Overlord       PS3
# 4399       63943             Tokyo Twilight Ghost Hunters       PS3
# 4400       63944                              Steins;Gate       PS3
#
#                            Publisher         Genre  Total_sales  USA_Sales  \
# 0                     Rockstar Games        Action         21.0       10.0
# 1                     Rockstar Games        Action         20.0        7.0
# 2                     Rockstar Games        Action         16.0       10.0
# 3                     Rockstar Games        Action         12.0        7.0
# 4     Sony Interactive Entertainment        Action         11.0        5.0
# ...                              ...           ...          ...        ...
# 4396                     Aksys Games  Visual+Novel          1.0        1.0
# 4397                             5pb  Visual+Novel          1.0        1.0
# 4398                     NIS America  Visual+Novel          1.0        1.0
# 4399                     Aksys Games  Visual+Novel          1.0        1.0
# 4400                             5pb  Visual+Novel          1.0        1.0
#
#       EUR_Sales  Japan_Sales Release_date    Year
# 0           1.0          1.0   26  Oct 04  2004.0
# 1          10.0          1.0   18  Nov 14  2014.0
# 2           6.0          1.0   17  Sep 13  2013.0
# 3           4.0          1.0   29  Apr 08  2008.0
# 4           4.0          1.0   10  May 16  2016.0
# ...         ...          ...          ...     ...
# 4396        0.0          1.0   10  Mar 15  2015.0
# 4397        1.0          1.0   18  Sep 15  2015.0
# 4398        1.0          1.0   14  Oct 14  2014.0
# 4399        0.0          1.0   10  Mar 15  2015.0
# 4400        1.0          1.0   18  Sep 15  2015.0
#
# [4401 rows x 11 columns]

# %%
counts = df['Genre'].value_counts()

fig, ax = plt.subplots(figsize=(12,6))
top_10 = counts[:10] # here we get the most frequent genres in the data set
plt.bar(range(10), top_10.values, align='center', tick_label=top_10.keys());
plt.title("Top 10 frequent genres");

# %%
df.groupby('Platforms')['Total_sales'].sum().sort_values(ascending=True).plot(
 kind='barh', y='Total_sales', figsize=(15,10), edgecolor='black')#here we show the general sales of games in diffrent platforms
plt.title('General sales of games on different platforms')
plt.xticks(rotation=42)
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
df.groupby('Platforms')['Total_sales'].sum().to_frame('Total_sales').sort_values(
by='Total_sales', ascending=False).head(10)
# Out:
#            Total_sales
# Platforms
# PS3             1579.0
# X360            1456.0
# PS2             1341.0
# PS4             1240.0
# Wii             1106.0
# DS               990.0
# PS               760.0
# 3DS              587.0
# NES              459.0
# GB               454.0

# %%
def heatmap_plot(data):

    plt.figure(figsize=(15,5))
    plt.title('Heatmap Correlation and Impact Distribution of all sales')
    sns.heatmap(data[['Total_sales', 'USA_Sales', 'EUR_Sales','Japan_Sales']].corr(), annot=True, cmap='mako', fmt='.3f' )# here we get the Correlation between sales in diffrent regions
    plt.show()

# %%
heatmap_plot(df)
